# %% [markdown]
# # Voting Mechanism Experiment Template
#
# ## Experiment #1
#
# (Use a unique identifier for the number next to "Experiment".)

# %% [markdown]
# ## Experiment Overview
#
# ### Key Question
#
# In Single-Choice Weighted Plurality, does adding weight for each NFTs produce different results (final winner) than one wallet, one vote?
#
# ### Procedure for Generating Data
#
# A **trial** consists of the following steps:
# **Step 1:** We load the actual TE Academy data available from the Otterspace subgraph, accessed on May 28. This gives us the real data available to voters.
#
# **Step 2:** We create two different weightings for the voters.
# A. *One Wallet, One Vote:* each voter is assigned a weight of 1.0, regardless of how many NFTs they hold. (This is also *uniform weighting*.)
# B. *Each NFT has a weight of 1.0*: each voter is assigned a weight equal to the number of NFTs they hold. Each NFT is worth 1.0.
#
# **Step 3:** We randomly assign voter choices.
#
# **Step 4:** We calculate the results (including final winner) for each weighting, and keep track of results in a DataFrame.
#
# We aim to calculate 100_000 trials.
#
# ### Measurement
#
# We measure which proportion of the time the two weightings produced the same winner.

# %% [markdown]
# ## Code for Simulation

# %%
# Standard Imports
import numpy as np
import pandas as pd
import os
from random import choice
from typing import Dict

import sys
sys.path.append('..')  # Add this line to include the directory above

# Custom imports
from custom_types import UserNFTs
from mechanisms.single_choice_weighted_plurality import SingleChoiceWeightedPlurality
from mechanisms.group_hug_mechanism import GroupHug

# %% [markdown]
# ## Importing the Data
#
# In the cell below, we are importing the available data as of May 28, 2024 regarding which users have which NFTs.

# %%
file_name = "../data/nft_data_may_28_2024_cleaned.csv"
file_exists = os.path.exists(file_name)
file_exists
# Out:
# True

# %% [markdown]
# # Key Question
#
# How often would a vote that incorporates credibility-weighting by NFTs produce a different outcome than simply doing one wallet, one vote? We use the actual TE Academy NFT data as of May 28 to look at this question.

# %% [markdown]
# ## Inputting Sample Data
#
# In the cells below, we load the data available from the `.csv` file in the `VOTER_DATA_FILENAME`.
#
# If you wish to use a different `.csv` file, change this line.

# %%
VOTER_DATA_FILENAME = "../data/nft_data_may_28_2024_cleaned.csv" # Adjust data here. 

voter_data = pd.read_csv(VOTER_DATA_FILENAME) #Convert to a Pandas DataFrame. 

# Sometimes there is a 
if ['Unnamed: 0'] in voter_data.columns:
    voter_data.drop(columns = ['Unnamed: 0'], 
                    inplace = True)
voter_data.set_index('ID', inplace = True)

# %%
sample_voters = voter_data.to_dict(orient='index')
sample_voters

# %%
# NOTE: This next step isn't strictly necessary at this stage. 
voters = {key: UserNFTs(sample_voters.get(key))
          for key, _ in sample_voters.items()
          }

# %%
voters
# Out:
# {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 0},
#  '0x049debbad61a20e21e872b06ef4f25be1253c802': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xa481db1ac55683dfb2847c02e417b7e411bcbbea': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x024bd3d1c3b6ba2277a744d7a99fbade9404a370': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xa0b026b4b9e19ff2cbf5afbd9a679d93dedc2242': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xfb2069bf55eb844694d8028df74dafe550821ffc': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x222cf246a3d56d61030ca49f5e6ffd6c20c3dc4f': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x5658f4b362e95c0bc32d5ce0051457882db92ee5': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 1,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x6697aeedc3eadbcfb25962c2045aedf438b4c1f2': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 0},
#  '0x6a7becf86b56fb68c948cb0a9fe9961370079190': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xc8eba9130f40a0ea9be530407e5b4f7199118864': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x6e3556f2c8f29559ed67642a1813b177f1871613': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x278a4bd5a8d09bcf11b1052ec3129a7efa75d213': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x28ddb1f987f1d433eb82eef644b006741977f456': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xfcbc07905fee2d64025461b8ddb27f77f256827f': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 1,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 1,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 1,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 1,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 0},
#  '0xa587b5aa3ddf49559cde74140456bf65d716f30a': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x6120faa647cd26cd6b2c1df880eff537065c6815': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x6d465d2081b799770d0ce7e755d8db1665903ffb': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x3b067af83f540cb827825a6ee5480441a4237e77': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x6a5cce4ac8b280ba789eb2e2bd3895b46133e5d4': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x58e39293ec6ce3f4d49c9a44bb76bd3e9b300130': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xc12abc0ce980c0949ec132e01dfa21eeab76b57b': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xcf653e70110315ddb9a11ae4fc36c6716e367a14': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x0eafb78d216a4d9ae725d3ef087143808695445c': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x79219e0514a0ed8b495c1bba0180cd12cde40242': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x6897abe0fd62b589260784b21f4ca3f78a0d8017': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x26cee1c87b7910c42ac83a3b617c2932f13b9044': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xee8bcf545bf80682b78d99f65742d34166cb0405': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x071903cc9a767a845fcd3ab7373e4d5328522481': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x9b9c0732cfecbd446eec92ba53dec31f2c9d88b1': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x4b8aa2db33df252cb0087de8d170d652e92eba02': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x1309df760d05a7e9ba396d9a6f8dd4305c4d25bf': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x1c651c3fedbf95307fb7a3a2fc07bc1e0753e5a9': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x033e64537940e0602e8f27f571d93904c0009486': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x0e272eceadbf50541f0a5c740082f177baf214d4': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x74fb4ba94a01b31424b5e1ab0d3ceff0ce6e6530': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x1210ba92eb82cc256213c78f0ef9d5212c7034a9': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x06b3b315cbf8b6f639508911976e2a58f1729e3b': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x4bce1d711ea4e033ad5e7d48d2f63fb24fe4b5e3': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x8242269882cd61de8ac878ac47d2a7432fc7bdee': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x7ee9033aad1d11a80f1c1e8d769feacbc97416db': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x2408a5b5a0c0e47cbe8f3b8c92b4361958b371e4': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x6292b5752db4aeb894428296accd3b707fd63b37': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0xd0ceca3064bd0f33483885f60ef40a71c125c638': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x1e5e0982e0b81f041f4b2668e8e1f300682b6ffa': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x88bde89f94b5e5dd1ef3c054a39961bcbb33bc44': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xe21a9bc92838fedb1f1b7a601f526816f28871c2': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x148d424f74c323d3950a8562760aa76e4c58615b': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x7003849fc9f3c70b5e90619f01522be94a38816f': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x27cdf5ca6cd49abd44fa030decf743b730310443': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xf9278a270d2100ea5e76e8d85ac712b2cb7ec685': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x9f771f779b88178de06291a2caa8e4bdc56dc184': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xdecc4ac78838d0178a418349b8ce6205f3c1905e': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x7137931f8e93928e835ec0946a8b78a8a8887900': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xfeee0f97af25b988e10417b3988e7720772e584a': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x8a79889c80e0e0ae07151acdc4537ffbace553f1': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x0db3c73e0fd8a19f086cfd303fda498f1b0221e3': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x912a7f5845f3fa8de3cb55772a3ba9c40d8e3aaa': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0xe3a17b05f01c1b28585ba2341ede238641cf32e7': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x358d930d71fa424ba4fee2a48a2e87fda55993e1': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 1,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x3e0cf03f718520f30300266dcf4db50ba12d3331': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 1,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 1,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xb9c62c6b68fa76bb5dad4279074ebdb6d72e3fec': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x85524e962b11cb82ea7baf3a00ceff92c6368db2': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x0b04f285b418ac07f12b7f60064d91d88f52c681': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x58ba947570d2f9b79882c444170a30827000b33a': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x18e2728b00678f886150caac59ce468b7f7a7af9': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xc68844831cd4af961eafb5bdffefa4fe698b70a2': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x8b9c66ff418aaddae7974ea006859e8ba8374aa3': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x3e31155a1c17c9f85e74828447aec412090a4622': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x01d517d706494ee4b01cbc8c699b529cd150edea': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xb6b774dcbd3091fd2a0423a201791d07700c25ef': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x560fbf887a1c98ae68ce71f018772d771d067781': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xa770a33cbf2e97a0eaed41afabddb997661cc24a': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x09e083c5653172131e1eef9a92e1eef64d86b154': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x336f3ca6cad963a70b8b64fade48c39a8de03b44': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xd26cf287da6ae872dd14a0151e2ee30a465990e8': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x35b2a533f02234342d9352fb9fbc1ee0c1703198': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xbbc9368898422cc9ffabef8ea66210d3d011512f': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x78390edbd4d560bcb3531d885058012041de24cb': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xba0e393d0d47ae81a22f27d68bac043bb64ddb31': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x72f2c4dd290d1c08d5763c812028655cbde3fb53': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xb13a55d8512aec4bf7b15067d733c4c3c68f2439': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xb78d439ba83baced629310207a215900e02d84a4': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xeaa24cde31a65ac72dff0ea673735d70625cf78a': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xfc0bbfe1e6391ad733b0016d41e50cfa2725717e': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xd3dbe133af71345a9a69894db354161ea7f441e9': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x4f766bfd800e0ff3260635fdd5fe8cfb666828d1': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0xc9d94be541ef24cd2e402dd5f6d15676d08474f7': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xe64063c7688db1ac863d0daa3dbca41ab4e6b465': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x4ff9371b4db3f0771e34f6cf4bd33312bc993e0a': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xb41ce218c36c7d95059bb21f82a6a720546cef29': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x51bef0ecac2dbbbbeff5c39d02e4ac49995185f1': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x0230b092ff54c1c7f17da5daa598117abe3e5715': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x0ce681173619e2599713ccc1c18779d6109671f1': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x18c5a9d555d197c9c42e63ca646716efdc20c676': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x0e950e75b652878e6a3d3ecb6e5797452a918a05': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 1,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xd6c197afb2d3f0c2549bb542b49ed089faca780f': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xcd8e1e3a577049f4e138db9f46a46a7e7bf3535d': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x325173bc8c0f68ea1384de0377786ea3284cf2fb': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xe9cc651f1cfaf869b88e8ba945c15e1d9c609ab5': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x82f9be60fc43ce39bbe40df22039380935ff58c8': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x47f793e8af738f4b61d7e2d207c6d29c713d1a84': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x4a16fc2d0826b50bbba9f4a1729f2e56cfca509d': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x0b96b6344b2a8d00b610992d0e6afb90c24bcfa3': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x91ab8278d8e018b79657c9c0d9abc876be4f9787': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 1},
#  '0x3e13da66f07b4b51f6496d4c6a7eeda50416692a': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x4fbfadf58cf32e7c616ed09d74318fe30c7071d4': {'NFTREP_V1': 1,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x6100c2ec0b1a0800dd246a7c6a922c21252be392': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xb2523a5a54813ff3acfef0b00f442a4ebba06ace': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x4c5b9006ac613ed4805f38b460c85484231f5ee4': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x7cdacc2e58c4daf29ab871958a714ef7398fa368': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x9ccebdb9c9871b0b8c18fe43f90760c83060bfba': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x0e5c4c325ba0cf3ebc82f0b15c318d6620e896a7': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0xfe161714d95ff338482b0200c2857cfa5e77a789': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x0cb0f554a2e8a5b7b5634f37840b037214925815': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 1,
#   'FUND_MOD5': 1},
#  '0x45a337477fe38793d90db641eecf8c5c624f062a': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 1,
#   'FUND_MOD2': 1,
#   'FUND_MOD3': 1,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x11b064a8ac721ee4a706c07128433548b8d2151b': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
# ...
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x577acd60f180802458a75188b74ed186087aa2b6': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x304eb9063fa42bd7841dc7cd6644b12385caa891': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xab6125047f67eee034cc4ec3a1c77ee3e77bff04': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x8bff44bbbeb73e15af02b6ca460c4255fa9291cd': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xc61221100589071804eaf2927ba351706349ce95': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xfb343bd470bc97450470aac23002bcc8d8549911': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x2fee53687906ba239602ed42cceee2ac8a4ada36': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x3a95ac31729140d6ac25c80b90eceec9b929eb9e': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x2879da9b66f3bd976ac2d786ad381bb9c07d4003': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x6916683ab95b955bb73caf8bab92700a2469d758': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 1,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x53683bcb9f386823a1e77e5f1720ac633d5d871d': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xba230c2295e4cf1a6f35dd4e4fe7437a18652f21': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x006c4972be1366114fa7b08773fc88b6083d5d18': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xcd6b97e773fd588ddf9462dd7e4f9869e120acff': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x891e02fd870432b1a8a0091f67fb8c7ca68740ff': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 1,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x77d40c87d423efb7ec576e80998a48377adf86df': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 1,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xb2821c0df0c414ff51d3e8033cba26df6aac587b': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 1,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xfede2257dc043f53a24ac7947218bacfb0013b09': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x5ce15dbcdf9a7c65ef7f31d11ccd49df4ecd860d': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x4888af8f72de3c1b5a1cb1c4f6b802ad7b8e51ff': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 1,
#   'SPEAKER_BARCAMP_PARIS_23': 1,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x4a9a40b2c44b7d32ecf4e0cc66f5304518ec0a59': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 1,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xa3fa5cbf856b10676e7e2ab2dc707a9f848c3af5': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 1,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x999e054df3e888a2dd20e678a436128e1bc796cf': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 1,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x8496767a1252a4981c16456f36316222d415b458': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 1,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xc31442c950e7151ded79386a506be868f61792ee': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x4d3b32abd5c3c6bec64fcb470e996fe843cf15d7': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xb7babe35ce543e2cf2f615cb1c792a2025feb572': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x98670f753c0f8dc419aae2095d13e2172ef680ac': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x1b21dcd95214f1407bffe799ce6e98be4e8fc8b8': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xab0dae31eb6bd328d57c9182dfb3a57b487bcca5': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 1,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x68b113c12b299d376b0f6a30081bb357054f025c': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x80382aeac43d7549d16d4740ffccb7ec517c51d3': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xb87b03fba8d60a6eb00f1c203cb91a611e3abbfb': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x3642ce3ed40832f2cb076114ee780da512e86753': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xdfe435e074e9830036aea0ea5c4fc506b7a11d5f': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0x4d6caa3e0983fac7b514d60339ebb538c5a85aae': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 1,
#   'TEAM_BARCAMP_PARIS_23': 0,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xeedb3e3cfd977cb9f00dadecf7cc80650e06c857': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 1,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0},
#  '0xa573ed241036d43c3e8a7b01d5721af0ed824746': {'NFTREP_V1': 0,
#   'SPEAKER_ETHCC_PARIS23': 0,
#   'STUDY_GROUP_HOST_C2_22_23': 0,
#   'ETHCC_23': 0,
#   'FUND_AUTHOR': 0,
#   'STUDY_GROUP_HOST_360_22': 0,
#   'STUDY_GROUP_HOST_FUND_22_23': 0,
#   'SPEAKER_BARCAMP_PARIS_23': 0,
#   'BARCAMP_PARIS_23': 0,
#   'TEAM_BARCAMP_PARIS_23': 1,
#   'FUND_MOD1': 0,
#   'FUND_MOD2': 0,
#   'FUND_MOD3': 0,
#   'FUND_MOD4': 0,
#   'FUND_MOD5': 0}}

# %% [markdown]
# When working with data, it's often helpful to see a particular entry to see what it looks like.

# %%
first_voter = list(sample_voters.values())[0]

# %% [markdown]
# ### Assigning Weights
#
# We need to create a dictionary of weights for the NFTS.
# The dictionary `NFT_weights` gives a weight of 1.0 to each NFT held by current TEA owners.

# %%
NFT_weights = {key: 1.0 
               for key
               in first_voter.keys()
               }
NFT_weights
# Out:
# {'NFTREP_V1': 1.0,
#  'SPEAKER_ETHCC_PARIS23': 1.0,
#  'STUDY_GROUP_HOST_C2_22_23': 1.0,
#  'ETHCC_23': 1.0,
#  'FUND_AUTHOR': 1.0,
#  'STUDY_GROUP_HOST_360_22': 1.0,
#  'STUDY_GROUP_HOST_FUND_22_23': 1.0,
#  'SPEAKER_BARCAMP_PARIS_23': 1.0,
#  'BARCAMP_PARIS_23': 1.0,
#  'TEAM_BARCAMP_PARIS_23': 1.0,
#  'FUND_MOD1': 1.0,
#  'FUND_MOD2': 1.0,
#  'FUND_MOD3': 1.0,
#  'FUND_MOD4': 1.0,
#  'FUND_MOD5': 1.0}

# %% [markdown]
# Single Choice Weighted Plurality requires that voters have some kind of weight.
# The function below takes a dictionary of voters with NFTs held, and a dictionary of weights.
# It returns the weight that each voter should hold, based on

# %%
def calc_voter_weights_from_NFT_weight(voters: Dict,
                                       nft_weights: Dict) -> Dict:
    """
    Given a list of voters, the NFTs they hold, and the 
    """
    new_dict = {}
    for voter in voters.keys():
        new_dict[voter] = {}
        new_dict[voter]["weight"] = 0
        for nft_name, nft_val in nft_weights.items():
            if voters.get(voter).get(nft_name):
                new_dict[voter]["weight"] += nft_val

    return new_dict

# %% [markdown]
# Now we use the function to assign each voter a weight, based on the NFTs.

# %%
voter_weights = calc_voter_weights_from_NFT_weight(voters,
                                                   NFT_weights)
voter_weights

# %% [markdown]
# As a comparison, we also create a version where each voter is assigned the same weight of 1.0, regardless of how many NFTs they hold.

# %%
uniform_weights = {voter: {}"weight": 1.0} for voter in sample_voters.keys()}
uniform_weights

# %% [markdown]
# ## Data Generation
#
# The data generation is below. Each voter is randomly assigned a choice to vote for.
# The results of using SingleChoiceWeightedPlurality are calculated for each trial, based on these voter choices and weights.
# These results are stored in a DataFrame.

# %%
# Create the mechanism
SCWPCalculator = SingleChoiceWeightedPlurality()

# Set the number of experiments
NUM_EXPERIMENTS = 10_000

# Create an empty DataFrame to store simulation results
results_list = [] 

for k in range(NUM_EXPERIMENTS):
    # Generate choices for each voter
    sample_choices = {
                   key: choice(["A","B","C","D"])
                   for key in sample_voters.keys()
                 }
    
    # Calculate who would win with weight of 1 per each NFT
    weighted_winner, weighted_results  = SCWPCalculator.calculate(voter_weights,
                            sample_choices)
    # Calculate who would win with uniform weight 
    uniform_winner, uniform_results = SCWPCalculator.calculate(uniform_weights,
                            sample_choices)
                   
    # Create an empty DataFrame to store simulation results
    results_list.append({'Experiment': k,
                        'weighted_winner': weighted_winner, 
                        'weighted_candidate_scores': weighted_results,
                        'uniform_winner': uniform_winner,
                        'uniform_candidate_scores': uniform_results,
                        "votes": sample_choices
                        }
                        )


results_df = pd.DataFrame(results_list)

#TODO: Refactor for speed if needed.

# %% [markdown]
# Let's see what the data looks like.

# %%
results_df
# Out:
#       Experiment weighted_winner  \
# 0              0               A
# 1              1               B
# 2              2               C
# 3              3               B
# 4              4               A
# ...          ...             ...
# 9995        9995               D
# 9996        9996               A
# 9997        9997               D
# 9998        9998               C
# 9999        9999               A
#
#                              weighted_candidate_scores uniform_winner  \
# 0     {'C': 241.0, 'D': 209.0, 'B': 160.0, 'A': 251.0}              A
# 1     {'A': 174.0, 'B': 246.0, 'D': 246.0, 'C': 195.0}              B
# 2     {'C': 230.0, 'A': 224.0, 'D': 206.0, 'B': 201.0}              C
# 3     {'B': 264.0, 'C': 198.0, 'A': 177.0, 'D': 222.0}              B
# 4     {'C': 222.0, 'D': 209.0, 'A': 250.0, 'B': 180.0}              D
# ...                                                ...            ...
# 9995  {'A': 209.0, 'B': 215.0, 'D': 219.0, 'C': 218.0}              B
# 9996  {'A': 226.0, 'B': 213.0, 'D': 220.0, 'C': 202.0}              D
# 9997  {'D': 239.0, 'C': 203.0, 'B': 211.0, 'A': 208.0}              D
# 9998  {'C': 247.0, 'B': 213.0, 'A': 212.0, 'D': 189.0}              C
# 9999  {'B': 198.0, 'C': 209.0, 'D': 222.0, 'A': 232.0}              C
#
#                            uniform_candidate_scores group_hug_winner  \
# 0      {'C': 90.0, 'D': 87.0, 'B': 74.0, 'A': 96.0}                C
# 1      {'A': 78.0, 'B': 96.0, 'D': 96.0, 'C': 77.0}                B
# 2      {'C': 93.0, 'A': 82.0, 'D': 81.0, 'B': 91.0}                C
# 3     {'B': 101.0, 'C': 77.0, 'A': 76.0, 'D': 93.0}                D
# 4     {'C': 77.0, 'D': 100.0, 'A': 95.0, 'B': 75.0}                A
# ...                                             ...              ...
# 9995   {'A': 77.0, 'B': 94.0, 'D': 82.0, 'C': 94.0}                B
# 9996   {'A': 87.0, 'B': 84.0, 'D': 88.0, 'C': 88.0}                C
# 9997   {'D': 94.0, 'C': 82.0, 'B': 88.0, 'A': 83.0}                B
# 9998   {'C': 94.0, 'B': 93.0, 'A': 80.0, 'D': 80.0}                B
# 9999   {'B': 85.0, 'C': 90.0, 'D': 82.0, 'A': 90.0}                A
#
#                          group_hug_results  \
# 0     {'C': 26, 'B': 26, 'A': 24, 'D': 24}
# 1     {'A': 20, 'B': 30, 'C': 24, 'D': 26}
# 2     {'C': 33, 'B': 16, 'A': 26, 'D': 25}
# 3     {'C': 25, 'B': 21, 'A': 25, 'D': 29}
# 4     {'C': 21, 'B': 21, 'A': 33, 'D': 25}
# ...                                    ...
# 9995  {'A': 21, 'B': 31, 'C': 31, 'D': 18}
# 9996  {'A': 22, 'B': 24, 'C': 28, 'D': 25}
# 9997  {'C': 26, 'B': 28, 'A': 18, 'D': 28}
# 9998  {'C': 21, 'B': 30, 'A': 30, 'D': 19}
# 9999  {'C': 26, 'B': 21, 'A': 30, 'D': 24}
#
#                                                   votes
# 0     {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
# 1     {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
# 2     {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
# 3     {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
# 4     {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
# ...                                                 ...
# 9995  {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
# 9996  {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
# 9997  {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
# 9998  {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
# 9999  {'0xbb8743ea733155fe5e81ed285aea72cc19b2ca87':...
#
# [10000 rows x 8 columns]

# %% [markdown]
# ## Measurements
#
# We calculate what proportion of the time the two methods gave the same result.

# %%
# Calculate proportion where they agreed. 

(results_df['weighted_winner'] == results_df['uniform_winner']).mean()
# Out:
# 0.6755
